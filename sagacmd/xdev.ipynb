# %%
import os
import time 
from glob import glob
from s_downxcale import gwrdownxcale
from s_ensemble import ensemble_prediction

# remove the excess d0 
# add on prep data into blocks 

out_dpath = "/home/ljp238/Downloads/SAGA_DEV"
ypath = "/media/ljp238/12TBWolf/BRCHIEVE/GDEM/TILES/N13E103/N13E103_gdtm_riofill0_egm.tif"
geoid_fn = "/media/ljp238/12TBWolf/BRCHIEVE/TILES12/N13E103/N13E103_egm08.tif"
xpath = "/media/ljp238/12TBWolf/BRCHIEVE/TILES12/N13E103/N13E103_edem_egm.tif"
#expname = "tile_dev" # TLS like ROI
expname = xpath.split('/')[-2]
name = 'GWRd_svs'
dw_weighting_list = [0,1,2,3]

outdir = f"{out_dpath}/{expname}"
os.makedirs(outdir, exist_ok=True)
opath =  os.path.join(outdir,f'{expname}_{name}.tif')

ti = time.perf_counter()
for dw_weighting in dw_weighting_list:
    # add logic if file already exist : grab the logic that modifies the file
    outpaths = gwrdownxcale(xpath, ypath, opath,geoid_fn, 
                            oaux=False, epsg_code=4979, clean=True,
                            search_range=0, search_radius=10, 
                            dw_weighting=dw_weighting, dw_idw_power=2.0, dw_bandwidth=1.0,
                            logistic=0, model_out=0, grid_system=None)


pfiles = glob(f"{outdir}/*fmin.tif")  #f'{expname}_{name}
rfile = xpath
assert len(pfiles) >= 1, "No file found for Prediction files..."
assert os.path.isfile(rfile), "reference file NoT Found..."

init_points = 10
n_iter=100
avg_raster, opt_raster = ensemble_prediction(pfiles, rfile,init_points, n_iter)

tf = time.perf_counter() - ti 
print(f'RUN.TIME {tf/60} min(s)')
# Out:
# ____________________________
#
#    #####   ##   #####    ##
#   ###     ###  ##       ###
#    ###   # ## ##  #### # ##
#     ### ##### ##    # #####
#  ##### #   ##  ##### #   ##
# ____________________________
#
# SAGA Version: 8.2.2
#
# ____________________________
# library path: /usr/lib/x86_64-linux-gnu/saga/
# library name: libstatistics_regression
# library     : statistics_regression
# tool        : GWR for Grid Downscaling
# identifier  : 14
# author      : O.Conrad (c) 2013
# processors  : 56 [56]
# ____________________________
#
# loading: N13E103_edem_egm
#
# 100%
# loading: N13E103_gdtm_riofill0_egm
#
#  99%
# [GWR for Grid Downscaling] Execution started...
#
# __________
# [GWR for Grid Downscaling] Parameters:
#
# Grid System: 0.000111; 9001x 9001y; 103x 13y
# Predictors: 1 object (N13E103_edem_egm)
# Regression: Regression
# Regression with Residual Correction: <not set>
# Dependent Variable: N13E103_gdtm_riofill0_egm
# Coefficient of Determination: Coefficient of Determination
# Residuals: Residuals
# Regression Parameters: No objects
# Logistic Regression: false
# Output of Model Parameters: false
# Search Range: local
# Search Distance [Cells]: 10
# Weighting Function: no distance weighting
#
# upscaling of predictors
#
#  99%
# model creation
#
#  99%downscaling
#
# 101%
# __________
# total execution time: 51000 milliseconds (51s)
#
# [GWR for Grid Downscaling] Execution succeeded (51s)
#
# Saving grid: /home/ljp238/Downloads/SAGA_DEV/N13E103/N13E103_GWRd_svs.tif...
# Export GeoTIFF
#
# __________
# [Export GeoTIFF] Parameters:
#
# Grid System: 0.000111; 9001x 9001y; 103x 13y
# Grid(s): 1 object (N13E103_GWRd_svs)
# File: /home/ljp238/Downloads/SAGA_DEV/N13E103/N13E103_GWRd_svs.tif
# Creation Options:
#
# Band 1
#
# 100%
# 100%
#
# [Export GeoTIFF] execution time: 03s
# okay
# Segmentation fault (core dumped)
# ! The file "/home/ljp238/Downloads/SAGA_DEV/N13E103/N13E103_GWRd_svs_dw0.tif" already exists.
# GWR Grid Downscaling completed.
# Cleaning up intermediate files...
# /home/ljp238/Downloads/SAGA_DEV/N13E103
# fmin_fn...
# bcor_fn...
# fminbcor_fn...
# Start time: 2025-05-15 15:58:54
# End time: 2025-05-15 16:00:25
# RUN.TIME = 1 minutes, 31 seconds
# ____________________________
#
#    #####   ##   #####    ##
#   ###     ###  ##       ###
#    ###   # ## ##  #### # ##
#     ### ##### ##    # #####
#  ##### #   ##  ##### #   ##
# ____________________________
#
# SAGA Version: 8.2.2
#
# ____________________________
# library path: /usr/lib/x86_64-linux-gnu/saga/
# library name: libstatistics_regression
# library     : statistics_regression
# tool        : GWR for Grid Downscaling
# identifier  : 14
# author      : O.Conrad (c) 2013
# processors  : 56 [56]
# ____________________________
#
# loading: N13E103_edem_egm
#
# 100%
# loading: N13E103_gdtm_riofill0_egm
#
#  99%
# [GWR for Grid Downscaling] Execution started...
#
# __________
# [GWR for Grid Downscaling] Parameters:
#
# Grid System: 0.000111; 9001x 9001y; 103x 13y
# Predictors: 1 object (N13E103_edem_egm)
# Regression: Regression
# Regression with Residual Correction: <not set>
# Dependent Variable: N13E103_gdtm_riofill0_egm
# Coefficient of Determination: Coefficient of Determination
# Residuals: Residuals
# Regression Parameters: No objects
# Logistic Regression: false
# Output of Model Parameters: false
# Search Range: local
# Search Distance [Cells]: 10
# Weighting Function: inverse distance to a power
# Power: 2
#
# upscaling of predictors
#
#  99%
# model creation
#
#  99%downscaling
#
# 101%
# __________
# total execution time: 50000 milliseconds (50s)
#
# [GWR for Grid Downscaling] Execution succeeded (50s)
#
# Saving grid: /home/ljp238/Downloads/SAGA_DEV/N13E103/N13E103_GWRd_svs.tif...
# Export GeoTIFF
#
# __________
# [Export GeoTIFF] Parameters:
#
# Grid System: 0.000111; 9001x 9001y; 103x 13y
# Grid(s): 1 object (N13E103_GWRd_svs)
# File: /home/ljp238/Downloads/SAGA_DEV/N13E103/N13E103_GWRd_svs.tif
# Creation Options:
#
# Band 1
#
# 100%
# 100%
#
# [Export GeoTIFF] execution time: 02s
# okay
# Segmentation fault (core dumped)
# ! The file "/home/ljp238/Downloads/SAGA_DEV/N13E103/N13E103_GWRd_svs_dw1.tif" already exists.
# GWR Grid Downscaling completed.
# Cleaning up intermediate files...
# /home/ljp238/Downloads/SAGA_DEV/N13E103
# fmin_fn...
# bcor_fn...
# fminbcor_fn...
# Start time: 2025-05-15 16:00:25
# End time: 2025-05-15 16:01:54
# RUN.TIME = 1 minutes, 28 seconds
# ____________________________
#
#    #####   ##   #####    ##
#   ###     ###  ##       ###
#    ###   # ## ##  #### # ##
#     ### ##### ##    # #####
#  ##### #   ##  ##### #   ##
# ____________________________
#
# SAGA Version: 8.2.2
#
# ____________________________
# library path: /usr/lib/x86_64-linux-gnu/saga/
# library name: libstatistics_regression
# library     : statistics_regression
# tool        : GWR for Grid Downscaling
# identifier  : 14
# author      : O.Conrad (c) 2013
# processors  : 56 [56]
# ____________________________
#
# loading: N13E103_edem_egm
#
# 100%
# loading: N13E103_gdtm_riofill0_egm
#
#  99%
# [GWR for Grid Downscaling] Execution started...
#
# __________
# [GWR for Grid Downscaling] Parameters:
#
# Grid System: 0.000111; 9001x 9001y; 103x 13y
# Predictors: 1 object (N13E103_edem_egm)
# Regression: Regression
# Regression with Residual Correction: <not set>
# Dependent Variable: N13E103_gdtm_riofill0_egm
# Coefficient of Determination: Coefficient of Determination
# Residuals: Residuals
# Regression Parameters: No objects
# Logistic Regression: false
# Output of Model Parameters: false
# Search Range: local
# Search Distance [Cells]: 10
# Weighting Function: exponential
# Bandwidth: 1
#
# upscaling of predictors
#
#  99%
# model creation
#
#  99%downscaling
#
# 101%
# __________
# total execution time: 52000 milliseconds (52s)
#
# [GWR for Grid Downscaling] Execution succeeded (52s)
#
# Saving grid: /home/ljp238/Downloads/SAGA_DEV/N13E103/N13E103_GWRd_svs.tif...
# Export GeoTIFF
#
# __________
# [Export GeoTIFF] Parameters:
#
# Grid System: 0.000111; 9001x 9001y; 103x 13y
# Grid(s): 1 object (N13E103_GWRd_svs)
# File: /home/ljp238/Downloads/SAGA_DEV/N13E103/N13E103_GWRd_svs.tif
# Creation Options:
#
# Band 1
#
# 100%
# 100%
#
# [Export GeoTIFF] execution time: 02s
# okay
# Segmentation fault (core dumped)
# ! The file "/home/ljp238/Downloads/SAGA_DEV/N13E103/N13E103_GWRd_svs_dw2.tif" already exists.
# GWR Grid Downscaling completed.
# Cleaning up intermediate files...
# /home/ljp238/Downloads/SAGA_DEV/N13E103
# fmin_fn...
# bcor_fn...
# fminbcor_fn...
# Start time: 2025-05-15 16:01:54
# End time: 2025-05-15 16:03:25
# RUN.TIME = 1 minutes, 31 seconds
# ____________________________
#
#    #####   ##   #####    ##
#   ###     ###  ##       ###
#    ###   # ## ##  #### # ##
#     ### ##### ##    # #####
#  ##### #   ##  ##### #   ##
# ____________________________
#
# SAGA Version: 8.2.2
#
# ____________________________
# library path: /usr/lib/x86_64-linux-gnu/saga/
# library name: libstatistics_regression
# library     : statistics_regression
# tool        : GWR for Grid Downscaling
# identifier  : 14
# author      : O.Conrad (c) 2013
# processors  : 56 [56]
# ____________________________
#
# loading: N13E103_edem_egm
#
# 100%
# loading: N13E103_gdtm_riofill0_egm
#
#  99%
# [GWR for Grid Downscaling] Execution started...
#
# __________
# [GWR for Grid Downscaling] Parameters:
#
# Grid System: 0.000111; 9001x 9001y; 103x 13y
# Predictors: 1 object (N13E103_edem_egm)
# Regression: Regression
# Regression with Residual Correction: <not set>
# Dependent Variable: N13E103_gdtm_riofill0_egm
# Coefficient of Determination: Coefficient of Determination
# Residuals: Residuals
# Regression Parameters: No objects
# Logistic Regression: false
# Output of Model Parameters: false
# Search Range: local
# Search Distance [Cells]: 10
# Weighting Function: gaussian
# Bandwidth: 1
#
# upscaling of predictors
#
#  99%
# model creation
#
#  99%downscaling
#
# 101%
# __________
# total execution time: 51000 milliseconds (51s)
#
# [GWR for Grid Downscaling] Execution succeeded (51s)
#
# Saving grid: /home/ljp238/Downloads/SAGA_DEV/N13E103/N13E103_GWRd_svs.tif...
# Export GeoTIFF
#
# __________
# [Export GeoTIFF] Parameters:
#
# Grid System: 0.000111; 9001x 9001y; 103x 13y
# Grid(s): 1 object (N13E103_GWRd_svs)
# File: /home/ljp238/Downloads/SAGA_DEV/N13E103/N13E103_GWRd_svs.tif
# Creation Options:
#
# Band 1
#
# 100%
# 100%
#
# [Export GeoTIFF] execution time: 03s
# okay
# Segmentation fault (core dumped)
# ! The file "/home/ljp238/Downloads/SAGA_DEV/N13E103/N13E103_GWRd_svs_dw3.tif" already exists.
# GWR Grid Downscaling completed.
# Cleaning up intermediate files...
# /home/ljp238/Downloads/SAGA_DEV/N13E103
# fmin_fn...
# bcor_fn...
# fminbcor_fn...
# Start time: 2025-05-15 16:03:25
# End time: 2025-05-15 16:04:55
# RUN.TIME = 1 minutes, 30 seconds
# Average ensemble saved to: /home/ljp238/Downloads/SAGA_DEV/N13E103/AVGe.tif
# num_predictions @4
# pbounds @{'w1': (0, 1), 'w2': (0, 1), 'w3': (0, 1), 'w4': (0, 1)}
# |   iter    |  target   |    w1     |    w2     |    w3     |    w4     |
# -------------------------------------------------------------------------
# | 1         | -13.27    | 0.417     | 0.7203    | 0.0001144 | 0.3023    |
# | 2         | -12.89    | 0.1468    | 0.09234   | 0.1863    | 0.3456    |
# | 3         | -12.97    | 0.3968    | 0.5388    | 0.4192    | 0.6852    |
# | 4         | -13.2     | 0.2045    | 0.8781    | 0.02739   | 0.6705    |
# | 5         | -13.15    | 0.4173    | 0.5587    | 0.1404    | 0.1981    |
# | 6         | -13.1     | 0.8007    | 0.9683    | 0.3134    | 0.6923    |
# | 7         | -13.27    | 0.8764    | 0.8946    | 0.08504   | 0.03905   |
# | 8         | -13.19    | 0.1698    | 0.8781    | 0.09835   | 0.4211    |
# | 9         | -12.94    | 0.9579    | 0.5332    | 0.6919    | 0.3155    |
# | 10        | -13.2     | 0.6865    | 0.8346    | 0.01829   | 0.7501    |
# | 11        | -12.62    | 0.2622    | 0.0       | 0.8607    | 0.3747    |
# | 12        | -12.38    | 0.0       | 0.0       | 1.0       | 0.0       |
# | 13        | -12.59    | 0.0       | 0.4448    | 1.0       | 0.0       |
# | 14        | -12.49    | 0.2458    | 0.0       | 1.0       | 0.0       |
# | 15        | -12.38    | 0.0       | 0.0       | 0.8376    | 0.0       |
# | 16        | -12.38    | 0.0       | 0.0       | 0.9185    | 0.0       |
# | 17        | -12.65    | 0.0       | 0.0       | 1.0       | 1.0       |
# | 18        | -12.81    | 1.0       | 0.0       | 1.0       | 1.0       |
# | 19        | -12.41    | 0.0       | 0.0       | 1.0       | 0.0815    |
# | 20        | -12.38    | 0.0       | 0.0       | 0.8793    | 0.0       |
# | 21        | -12.38    | 0.0       | 0.0       | 0.7002    | 0.0       |
# | 22        | -12.38    | 0.0       | 0.0       | 0.9592    | 0.0       |
# | 23        | -12.38    | 0.0       | 0.0       | 0.7577    | 0.0       |
# | 24        | -12.85    | 0.0       | 1.0       | 1.0       | 1.0       |
# | 25        | -12.38    | 0.0       | 0.0       | 0.5966    | 0.0       |
# | 26        | -12.38    | 0.0       | 0.0       | 0.5966    | 0.0       |
# | 27        | -12.38    | 0.0       | 0.0       | 0.5966    | 0.0       |
# | 28        | -12.38    | 0.0       | 0.0       | 0.5966    | 0.0       |
# | 29        | -12.38    | 0.0       | 0.0       | 0.485     | 0.0       |
# | 30        | -12.38    | 0.0       | 0.0       | 0.485     | 0.0       |
# | 31        | -12.38    | 0.0       | 0.0       | 0.485     | 0.0       |
# | 32        | -12.38    | 0.0       | 0.0       | 0.7938    | 0.0       |
# | 33        | -12.38    | 0.0       | 0.0       | 0.7938    | 0.0       |
# | 34        | -12.38    | 0.0       | 0.0       | 0.5332    | 0.0       |
# | 35        | -12.38    | 0.0       | 0.0       | 0.5281    | 0.0       |
# | 36        | -12.38    | 0.0       | 0.0       | 0.1638    | 0.0       |
# | 37        | -12.38    | 0.0       | 0.0       | 0.2818    | 0.0       |
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[1], line 40
#      38 init_points = 10
#      39 n_iter=100
# ---> 40 avg_raster, opt_raster = ensemble_prediction(pfiles, rfile,init_points, n_iter)
#      42 tf = time.perf_counter() - ti
#      43 print(f'RUN.TIME {tf/60} min(s)')
#
# File ~/Documents/UoE/GTDX/sagacmd/s_ensemble.py:97, in ensemble_prediction(pred_paths, ref_path, init_points, n_iter, avge, opte)
#      95 weights = [w1, w2, w3, w4]
#      96 ensemble = np.average(np.stack(prediction_arrays), axis=0, weights=weights)
# ---> 97 return -calculate_rmse(ensemble, reference_array)
#
# File ~/miniconda3/envs/agluon/lib/python3.11/site-packages/bayes_opt/bayesian_optimization.py:338, in BayesianOptimization.maximize(self, init_points, n_iter)
#     336     x_probe = self.suggest()
#     337     iteration += 1
# --> 338 self.probe(x_probe, lazy=False)
#     340 if self._bounds_transformer and iteration > 0:
#     341     # The bounds transformer should only modify the bounds after
#     342     # the init_points points (only for the true iterations)
#     343     self.set_bounds(self._bounds_transformer.transform(self._space))
#
# File ~/miniconda3/envs/agluon/lib/python3.11/site-packages/bayes_opt/bayesian_optimization.py:270, in BayesianOptimization.probe(self, params, lazy)
#     268     self._queue.append(params)
#     269 else:
# --> 270     self._space.probe(params)
#     271     self.dispatch(Events.OPTIMIZATION_STEP)
#
# File ~/miniconda3/envs/agluon/lib/python3.11/site-packages/bayes_opt/target_space.py:418, in TargetSpace.probe(self, params)
#     416     error_msg = "No target function has been provided."
#     417     raise ValueError(error_msg)
# --> 418 target = self.target_func(**dict_params)
#     420 if self._constraint is None:
#     421     self.register(x, target)
#
# File ~/Documents/UoE/GTDX/sagacmd/s_ensemble.py:84, in bayesian_optimization_function(w1, w2, w3, w4)
#      78     prediction_arrays.append(array)
#      80 reference_array, _, _ = load_raster(ref_path)
# ---> 84 if avge:
#      85     avg_ensemble_array = average_ensemble(prediction_arrays)
#      86     avge_fn = os.path.join(output_dir, "AVGe.tif")
#
# File ~/miniconda3/envs/agluon/lib/python3.11/site-packages/numpy/lib/function_base.py:550, in average(a, axis, weights, returned, keepdims)
#     548     scl = wgt.sum(axis=axis, dtype=result_dtype, **keepdims_kw)
#     549     if np.any(scl == 0.0):
# --> 550         raise ZeroDivisionError(
#     551             "Weights sum to zero, can't be normalized")
#     553     avg = avg_as_array = np.multiply(a, wgt,
#     554                       dtype=result_dtype).sum(axis, **keepdims_kw) / scl
#     556 if returned:
#
# ZeroDivisionError: Weights sum to zero, can't be normalized
