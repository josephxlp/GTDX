# %% [markdown]
# https://openweathermap.org/price

# %% [markdown]
# - First 1000 API calls per day are FREE
# - Each additional call costs 0.0012 GBP

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# open an student account, and try to build a service around it
#https://docs.openweather.co.uk/our-initiatives/student-initiative
#https://docs.openweather.co.uk/our-initiatives
#https://home.openweathermap.org/marketplace

# %%
#name : free-testing
# api_key : check the emails recieved
#testing :https://colab.research.google.com/drive/1DzlXBbS-TLT1kPFvj00kOK3EE4gVrLob#scrollTo=Dee4XfG5yVdd

# %%
#https://dashboard.openweather.co.uk/home
# can i embed this to my webapplication
